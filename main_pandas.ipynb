# %%
import pandas as pd

# %%
data={
    'name':['a','b','c'],
    'age':[22,34,24]
}
df=pd.DataFrame(data)
df
# Out:
#   name  age
# 0    a   22
# 1    b   34
# 2    c   24

# %%
df=pd.read_csv('./data.csv')
df
# Out:
#     Name  Age  Salary
# 0    Ali   23   15400
# 1  Pouya   21    4500
# 2  Javad   24    5200
# 3    Ali   23   15400
# 4  Pouya   21    4500
# 5  Javad   24    5200
# 6    Ali   23   15400
# 7  Pouya   21    4500
# 8  Javad   24    5200

# %%
df.head()
# Out:
#     Name  Age  Salary
# 0    Ali   23   15400
# 1  Pouya   21    4500
# 2  Javad   24    5200
# 3    Ali   23   15400
# 4  Pouya   21    4500

# %%
df.describe()
# Out:
#              Age        Salary
# count   9.000000      9.000000
# mean   22.666667   8366.666667
# std     1.322876   5283.701354
# min    21.000000   4500.000000
# 25%    21.000000   4500.000000
# 50%    23.000000   5200.000000
# 75%    24.000000  15400.000000
# max    24.000000  15400.000000

# %%
df['Name']
# Out:
# 0      Ali
# 1    Pouya
# 2    Javad
# 3      Ali
# 4    Pouya
# 5    Javad
# 6      Ali
# 7    Pouya
# 8    Javad
# Name: Name, dtype: object

# %%
df.iloc[2:]
# Out:
#     Name  Age  Salary
# 2  Javad   24    5200
# 3    Ali   23   15400
# 4  Pouya   21    4500
# 5  Javad   24    5200
# 6    Ali   23   15400
# 7  Pouya   21    4500
# 8  Javad   24    5200

# %%
df.iloc[2,:]
# Out:
# Name      Javad
# Age          24
# Salary     5200
# Name: 2, dtype: object

# %%
df.iloc[3,1]
# Out:
# np.int64(23)

# %%
filter_df=df[df['Salary']>4500]
filter_df
# Out:
#     Name  Age  Salary
# 0    Ali   23   15400
# 2  Javad   24    5200
# 3    Ali   23   15400
# 5  Javad   24    5200
# 6    Ali   23   15400
# 8  Javad   24    5200

# %%
df_sorted=df.sort_values('Salary')
df_sorted
# Out:
#     Name  Age  Salary
# 1  Pouya   21    4500
# 4  Pouya   21    4500
# 7  Pouya   21    4500
# 2  Javad   24    5200
# 5  Javad   24    5200
# 8  Javad   24    5200
# 3    Ali   23   15400
# 0    Ali   23   15400
# 6    Ali   23   15400

# %%
df
# Out:
#     Name  Age  Salary
# 0    Ali   23   15400
# 1  Pouya   21    4500
# 2  Javad   24    5200
# 3    Ali   23   15400
# 4  Pouya   21    4500
# 5  Javad   24    5200
# 6    Ali   23   15400
# 7  Pouya   21    4500
# 8  Javad   24    5200

# %%
subset=df.loc[2:4,['Name','Age']]
subset
# Out:
#     Name  Age
# 2  Javad   24
# 3    Ali   23
# 4  Pouya   21

# %%
df_grouped=df.groupby('Age')
df_grouped.count()
# Out:
#      Name  Salary
# Age
# 21      3       3
# 23      3       3
# 24      3       3

# %%
df['test']=[1,2,3,4,5,6,7,8,9]
df
# Out:
#     Name  Age  Salary  test
# 0    Ali   23   15400     1
# 1  Pouya   21    4500     2
# 2  Javad   24    5200     3
# 3    Ali   23   15400     4
# 4  Pouya   21    4500     5
# 5  Javad   24    5200     6
# 6    Ali   23   15400     7
# 7  Pouya   21    4500     8
# 8  Javad   24    5200     9

# %%
df.drop('test',axis=1,inplace=True)
df
# Out:
#     Name  Age  Salary
# 0    Ali   23   15400
# 1  Pouya   21    4500
# 2  Javad   24    5200
# 3    Ali   23   15400
# 4  Pouya   21    4500
# 5  Javad   24    5200
# 6    Ali   23   15400
# 7  Pouya   21    4500
# 8  Javad   24    5200

# %%
len(df)
# Out:
# 9

# %%
df.loc[len(df)]={
    'Name':'test',
    'Age':22
}
df
# Out:
#     Name  Age   Salary
# 0    Ali   23  15400.0
# 1  Pouya   21   4500.0
# 2  Javad   24   5200.0
# 3    Ali   23  15400.0
# 4  Pouya   21   4500.0
# 5  Javad   24   5200.0
# 6    Ali   23  15400.0
# 7  Pouya   21   4500.0
# 8  Javad   24   5200.0
# 9   test   22      NaN

# %%
df.isna()
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False
# 7  False  False   False
# 8  False  False   False
# 9  False  False    True

# %%
df=df.dropna()
df
# Out:
#     Name  Age   Salary
# 0    Ali   23  15400.0
# 1  Pouya   21   4500.0
# 2  Javad   24   5200.0
# 3    Ali   23  15400.0
# 4  Pouya   21   4500.0
# 5  Javad   24   5200.0
# 6    Ali   23  15400.0
# 7  Pouya   21   4500.0
# 8  Javad   24   5200.0

# %%
df
# Out:
#     Name  Age   Salary
# 0    Ali   23  15400.0
# 1  Pouya   21   4500.0
# 2  Javad   24   5200.0
# 3    Ali   23  15400.0
# 4  Pouya   21   4500.0
# 5  Javad   24   5200.0
# 6    Ali   23  15400.0
# 7  Pouya   21   4500.0
# 8  Javad   24   5200.0
# 9   test   22      NaN

# %%
df1=df.fillna(0)
df1
# Out:
#     Name  Age   Salary
# 0    Ali   23  15400.0
# 1  Pouya   21   4500.0
# 2  Javad   24   5200.0
# 3    Ali   23  15400.0
# 4  Pouya   21   4500.0
# 5  Javad   24   5200.0
# 6    Ali   23  15400.0
# 7  Pouya   21   4500.0
# 8  Javad   24   5200.0
# 9   test   22      0.0

# %%
df.to_csv('newdata.csv')
